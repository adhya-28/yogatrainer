# %%
import cv2
import mediapipe as mp
import numpy as np
import pyttsx3
from tkinter import *
from tkinter import ttk
from PIL import ImageTk, Image
import matplotlib
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pickle

engine = pyttsx3.init()

pickle_in = open("studentmodel.pickel", "rb")
model = pickle.load(pickle_in)

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

def calculate_angle(a,b,c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle 
def say(command): 
    engine.say(command) 
    engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 17
#      14 engine = pyttsx3.init()
#      16 pickle_in = open("studentmodel.pickel", "rb")
# ---> 17 model = pickle.load(pickle_in)
#      19 mp_drawing = mp.solutions.drawing_utils
#      20 mp_pose = mp.solutions.pose
#
# File _tree.pyx:867, in sklearn.tree._tree.Tree.__setstate__()
#
# File _tree.pyx:1573, in sklearn.tree._tree._check_node_ndarray()
#
# ValueError: node array from the pickle has an incompatible dtype:
# - expected: {'names': ['left_child', 'right_child', 'feature', 'threshold', 'impurity', 'n_node_samples', 'weighted_n_node_samples', 'missing_go_to_left'], 'formats': ['<i8', '<i8', '<i8', '<f8', '<f8', '<i8', '<f8', 'u1'], 'offsets': [0, 8, 16, 24, 32, 40, 48, 56], 'itemsize': 64}
# ...

# %%
def jumping_jack(x):
    cap = cv2.VideoCapture(0)
    count = 0 

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                landmarks = results.pose_landmarks.landmark

                a = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
                b = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
                c = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]

                angle = calculate_angle(a, b, c)

                cv2.putText(image, str(angle),tuple(np.multiply(b, [640, 480]).astype(int)),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

                if angle <87:
                    flag = 1
                if angle >104 and flag==1:
                    flag=0
                    count +=1

            except:
                pass

            cv2.putText(image, 'Count', (15,12),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(count), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

            cv2.imshow('Jumpming jack', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            if count>x:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
def right_leg_rise(x):
    cap = cv2.VideoCapture(0)
    count = 0 

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                landmarks = results.pose_landmarks.landmark

                a = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
                b = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
                c = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]

                angle = calculate_angle(a, b, c)

                cv2.putText(image, str(angle),tuple(np.multiply(b, [640, 480]).astype(int)),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

                if angle <100:
                    flag = 1
                if angle >120 and flag==1:
                    flag=0
                    count +=1

            except:
                pass

            cv2.putText(image, 'Count', (15,12),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(count), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

            cv2.imshow('Right leg rise', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            if count>x:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
def left_leg_rise(x):
    cap = cv2.VideoCapture(0)
    count = 0 

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                landmarks = results.pose_landmarks.landmark

                a = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
                b = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
                c = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]

                angle = calculate_angle(a, b, c)

                cv2.putText(image, str(angle),tuple(np.multiply(b, [640, 480]).astype(int)),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

                if angle <100:
                    flag = 1
                if angle >120 and flag==1:
                    flag=0
                    count +=1

            except:
                pass

            cv2.putText(image, 'Count', (15,12),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(count), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

            cv2.imshow('Left leg rise', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            if count>x:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
def l_high_knee_rise(x):
    cap = cv2.VideoCapture(0)
    count = 0 
    flag = 1
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                landmarks = results.pose_landmarks.landmark

                if landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y <landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y:
                    flag = 0
                if landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y >landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y and flag==0:
                    flag=1
                    count +=1

            except:
                pass

            cv2.putText(image, 'Count', (15,12),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(count), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

            cv2.imshow('Left knee rise', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            if count>x:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
def r_high_knee_rise(x):
    cap = cv2.VideoCapture(0)
    count = 0 
    flag = 1
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                landmarks = results.pose_landmarks.landmark

                if landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y <landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y:
                    flag = 0
                if landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y >landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y and flag==0:
                    flag=1
                    count +=1

            except:
                pass

            cv2.putText(image, 'Count', (15,12),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(count), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

            cv2.imshow('Right knee rise', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            if count>x:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
def side_bend(x):    
    cap = cv2.VideoCapture(0)
    count = 0 
    flag = 1
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()

            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = pose.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                landmarks = results.pose_landmarks.landmark

                if landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y >landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y and landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x <landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x:
                    flag = 0
                if landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y >landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y and  landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x >landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x and flag==0:
                    flag=1
                    count +=1
                #print(landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x)              
            except:
                pass

            cv2.putText(image, 'Count', (15,12),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(count), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)

            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

            cv2.imshow('Side bend', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            if count>x:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
def start_yoga():
    dd="tree"
    cap = cv2.VideoCapture(0)
    count = 0
    frameloc=[]
    pred=''
    count1=0
    count2=0
    count3=0
    count4=0
    count5=0
    t=20
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            while cap.isOpened():
                ret, frame = cap.read()
                image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                image.flags.writeable = False
                results = pose.process(image)
                image.flags.writeable = True
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                try:
                    landmarks = results.pose_landmarks.landmark
                    a = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
                    b = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
                    c = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                    d = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                    e = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                    f = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                    g = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
                    h = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                    i = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
                    j = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
                    k = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
                    l = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
                    if landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].visibility>0.5:
                        feature = np.concatenate((a,b,c,d,e,f,g,h,i,j,k,l))
                        frameloc.append(feature)
                        angle= calculate_angle(h,j,l)
                        count+=1
                        if count>3:
                            predictions = model.predict(frameloc)
                            frameloc=[]
                            count=0
                            predictions=list(predictions)
                            #print(predictions,calculate_angle(h,j,l),calculate_angle(g,i,k))
                            #print(count1,count2,count3,count4,count5)
                            if predictions.count(3)==4 and calculate_angle(h,j,l)<100 and count1<t+1:
                                    pred='tree'
                                    count1+=1
                                    if landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y <landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y and flag==0:
                                        say("raise your hands")
                            elif predictions.count(4)==4 and calculate_angle(h,j,l)<150 and calculate_angle(g,i,k)<150 and count1>=t and count2<=t:
                                    pred='goddess'
                                    count2+=1
                                    if landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y <landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y and flag==0:
                                        say("raise your hands")
                            elif predictions.count(2)==4 and count2>=t and count3<=t :
                                    pred='plank'
                                    count3+=1
                                    if calculate_angle(h,j,l)<170:
                                        say('keep your leg straight')
                            elif predictions.count(4)==4 and calculate_angle(g,i,k)<150 and calculate_angle(h,j,l)>165 and count3>=t and count4<=t:
                                    pred='warrior'
                                    count4+=1
                            elif predictions.count(0)==4 and calculate_angle(i,g,e)<150 and count4>=t:
                                    pred='downdog'
                                    count5+=1
                                
                except:
                    pass 
                
                if count4==t:
                    dd="Downdog"
                if count3==t:
                    dd="warrior"
                if count2==t:
                    dd="plank"
                if count1==t:
                    dd="goddess"
            
                cv2.putText(image, "current pose :" +str(dd), (10,400), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
                cv2.putText(image, str(pred), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
                pred=''
                mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)               

                cv2.imshow('Yoga', image)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    cap.release()
                    cv2.destroyAllWindows()
                    break
                if count5==t:
                    cap.release()
                    cv2.destroyAllWindows()
                    break

# %%
def exercise():

    print("starting exercise")
    k=jumping_jack(10)
    l=right_leg_rise(10)
    m=left_leg_rise(10)
    n=l_high_knee_rise(10)
    o=r_high_knee_rise(10)
    p=side_bend(10)

def yog():
    print("starting yoga")
    start_yoga()

# %%
root = Tk()
pw = ttk.PanedWindow(root, orient=HORIZONTAL)
pw.pack(fill=BOTH, expand=True)
frame1 = Frame(pw, relief=SUNKEN,bg='#daf0f0')

bg = PhotoImage(file = "bg_img.png")
label1 = Label( root, image = bg)
label1.place(x = 0,y = 0)
lbl1 = Label(frame1, text = "Personal Exercise and Yoga Trainer",bg='#daf0f0',fg='black',font=("Felix Titling", 30))
lbl1.place(x=110,y=20, relwidth=1, relheight=1)
lbl1 = Label(frame1, text = "Name :",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=130,y=110)
lbl1 = Label(frame1, text = "Ayana",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=230,y=110)
lbl1 = Label(frame1, text = "Age :",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=130,y=150)
lbl1 = Label(frame1, text = "22",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=230,y=150)
lbl1 = Label(frame1, text = "Height :",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=130,y=190)
lbl1 = Label(frame1, text = "160",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=230,y=190)
lbl1 = Label(frame1, text = "Weight:",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=130,y=230)
lbl1 = Label(frame1, text = "62",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=230,y=230)
lbl1 = Label(frame1, text = "BMI :",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=130,y=270)
lbl1 = Label(frame1, text = "24.2",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=230,y=270)
lbl1 = Label(frame1, text = "Start Exercise",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=400,y=120)
btn1 = Button(frame1, text="Start", command = exercise,bg='#6cd4d4',fg='black',width=10)
btn1.place(x=600,y=120)
lbl1 = Label(frame1, text = "Start Yoga",bg='#daf0f0',fg='black',font=("Helvetica", 20))
lbl1.place(x=400,y=170)
btn1 = Button(frame1, text="Start", command = yog,bg='#6cd4d4',fg='black',width=10,relief=RAISED)
btn1.place(x=600,y=170)

label1.image = bg

pw.add(frame1, weight=1)

root.geometry("1000x700")
root.title("Yoga trainer")
root.mainloop()
